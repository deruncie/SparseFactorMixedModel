# %%
source('model_setup_simulation.R')
# Out:
# Loading required package: coda
# Loading required package: MASS
# ##
# ## Markov Chain Monte Carlo Package (MCMCpack)
# ## Copyright (C) 2003-2017 Andrew D. Martin, Kevin M. Quinn, and Jong Hee Park
# ##
# ## Support provided by the U.S. National Science Foundation
# ## (Grants SES-0350646 and SES-0350613)
# ##
# Warning message in dir.create(folder):
# “'R_rep_2' already exists”
# [1] "Initializing"
# [1] "Run 1"
#   |======================================================================| 100%
# Time difference of 2.466129 secs
#  [1] NA NA NA NA NA NA NA NA NA NA
# [1] "0 files"
#
#  Current iteration: 100, Posterior_samples: 0
#  Current factor dimension: 20 factors
#  Total time: 2.466129 secs
# [1] "Run 2"
#   |======================================================================| 100%
# Time difference of 6.462371 secs
#  [1] 0.3064211 0.4522494 0.4126798 0.6397432 0.5611968 0.3521219 0.3011123
#  [8] 0.5890183 0.2257980 0.3016601
# [1] "12 files"
#
# ...

# %%
pwd()
# Out:
# Error in pwd(): could not find function "pwd"
# Traceback:

# %%
getwd()
# Out:
# [1] "/Users/der7/Box Sync/DER_projects/BSFG/R_BSFG/R_rep_2"

# %%
BSFG_state
# Out:
#  Current iteration: 400, Posterior_samples: 150
#  Current factor dimension: 20 factors
#  Total time: 21.78773 secs

# %%
names(BSFG_state)
# Out:
# [1] "data_matrices"  "priors"         "run_parameters" "run_variables"
# [5] "setup"          "RNG"            "current_state"  "Posterior"

# %%
summary(BSFG_state)
# Out:
#  Model dimensions: fixed = 5, random = 500
#  Sampler: fast_BSFG
#  Current iteration: 400, Posterior_samples: 150
#  Current factor dimension: 20 factors
#  Total time: 21.78773 secs

# %%
BSFG_state$data_matrices$X
# Out:
# 500 x 5 sparse Matrix of class "dgCMatrix"
#     (Intercept)       Fixed1       Fixed2        Fixed3       Fixed4
# 1             1  0.798620686 -0.449363808 -0.8665154541  1.120018085
# 2             1  2.008651402  0.244508515 -1.4552684838 -0.294040291
# 3             1  0.597346511  1.404034532  1.3647666293 -0.042198571
# 4             1  1.353044337  0.856850374 -1.4695197795 -0.563796926
# 5             1  0.007113979 -0.049828268  0.2639616377 -0.041810883
# 6             1 -0.681518114 -0.096982264 -0.0396666427  1.780294017
# 7             1  0.801218302  1.312222174  1.2900468555 -1.766805799
# 8             1 -0.606133371  1.003729618 -1.4282395611 -1.486812976
# 9             1 -0.727218775  0.878356913  0.5357363783 -1.008636708
# 10            1  1.047046190 -0.751204403  0.4706291128  1.063106450
# 11            1 -1.594877181 -1.970677090  1.5044583501  0.144771563
# 12            1 -0.053721701  0.337956747  0.4844117482 -0.822045420
# ...
