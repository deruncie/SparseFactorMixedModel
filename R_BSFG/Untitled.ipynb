# %% [markdown]
# # This is free text
# asdf
# adsf
# asdf

# %%
source('model_setup_simulation.R')
# Out:
# Loading required package: coda
# Loading required package: MASS
# ##
# ## Markov Chain Monte Carlo Package (MCMCpack)
# ## Copyright (C) 2003-2017 Andrew D. Martin, Kevin M. Quinn, and Jong Hee Park
# ##
# ## Support provided by the U.S. National Science Foundation
# ## (Grants SES-0350646 and SES-0350613)
# ##
# Warning message in dir.create(folder):
# “'R_rep_2' already exists”
# [1] "Initializing"
# [1] "Run 1"
#   |======================================================================| 100%
# Time difference of 2.563549 secs
#  [1] NA NA NA NA NA NA NA NA NA NA
# [1] "0 files"
#
#  Current iteration: 100, Posterior_samples: 0
#  Current factor dimension: 20 factors
#  Total time: 2.563549 secs
# [1] "Run 2"
#   |======================================================================| 100%
# Time difference of 6.543808 secs
#  [1] 0.41061034 0.35659335 0.33610013 0.22315732 0.28438253 0.39024103
#  [7] 0.36338106 0.23316543 0.18986121 0.09163895
# [1] "12 files"
#
# ...

# %%
getwd()
BSFG_state
names(BSFG_state)
summary(BSFG_state)
# Out:
# [1] "/Users/der7/Box Sync/DER_projects/BSFG/R_BSFG/R_rep_2"
